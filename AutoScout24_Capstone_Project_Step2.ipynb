# %% [markdown]
# <img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY" style="display:block; margin:auto;" width='400' height='200'>
#
# <p style="background-color:romance; color:plum; font-size:220%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height:1.4; font-weight:bold; text-transform: uppercase;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src="https://i.ibb.co/wJW61Y2/Used-cars.jpg" style="display:block; margin:auto;" width='600' height='200'>
#
# <p style="background-color:romance; color:jaguar; font-size:3em; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height:1.4; font-weight:bolder; text-transform:capitalize;"><strong>The Capstone Project of Data Analytics Module</strong></p>
#
# <p style="background-color:romance; color:jaguar; font-size:2em; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height:1.4; font-weight:normal; text-transform:capitalize;">Car Price Prediction EDA</p>
#
# <basefont size="2" face ="arial, verdana, sans-serif" color="jaguar">

# %% [markdown]
# <a id="content"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4; font-weight:bold; text-transform:capitalize;">Content</p>
#
# * [Introduction](#0)
# <!-- * [About Dataset](#1) -->
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [The End of the Project](#10)

# %% [markdown]
# <a id="0"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4; font-weight:bold; text-transform:capitalize;">Introduction</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# <p style="font-size:22px; font-weight:bold;">Introduction</p>
#
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# <p style="font-size:18px; font-weight:bold;">Some Reminders on Exploratory data analysis (EDA)</p>
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">PART- 02 (Handling with Missing Values)</p>
#
# <a id="1"></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams

import plotly 
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# !pip install skimpy
from skimpy import clean_columns

import re 
import warnings
# Suppressing a warning 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# Environment settings:
# pd.options.display.max_rows
# https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.set_option.html
pd.set_option('display.float_format', lambda x: '%.2f' % x)
# Set it to None to display ALL columns in the dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_seq_items', None)
# The maximum width in characters of a column
pd.set_option('display.max_colwidth', 80)
# Set it None to display ALL rows in the dataframe
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ### Reading the Data

# %%
df_original = pd.read_csv('cleaned_scout_car_1.csv')
df = df_original.copy()

# %% [markdown]
# ### Checking the features

# %%
df.shape
# Out:
# (15919, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   make_model             15919 non-null  object
#  1   body_type              15569 non-null  object
#  2   price                  15919 non-null  int64
#  3   vat                    11406 non-null  object
#  4   km                     14895 non-null  float64
#  5   prev_owner             9091 non-null   float64
#  6   hp                     15831 non-null  float64
#  7   type                   15917 non-null  object
#  8   previous_owners        9279 non-null   float64
#  9   warranty               9156 non-null   object
#  10  body_color             15322 non-null  object
#  11  paint_type             10147 non-null  object
#  12  nr_of_doors            15707 non-null  float64
#  13  nr_of_seats            14942 non-null  float64
# ...

# %% [markdown]
# ### Checking the statistical values

# %%
df.describe().T
# Out:
#                          count     mean      std   min      25%      50%  \
# price                 15919.00 18019.90  7386.17 13.00 12850.00 16900.00
# km                    14895.00 34130.13 37352.98  0.00  5153.00 22740.00
# prev_owner             9091.00     1.09     0.29  1.00     1.00     1.00
# hp                    15831.00    88.37    26.84  1.00    66.00    85.00
# previous_owners        9279.00     1.07     0.33  0.00     1.00     1.00
# nr_of_doors           15707.00     4.66     0.65  1.00     4.00     5.00
# nr_of_seats           14942.00     4.95     0.49  2.00     5.00     5.00
# cylinders             10239.00     3.80     0.42  1.00     4.00     4.00
# gears                 11207.00     5.92     0.85  1.00     5.00     6.00
# age                   14322.00     1.54     1.08  0.00     1.00     1.00
# warranty_months        4853.00    21.93    15.77  1.00    12.00    12.00
# displacement_cc       15423.00  1423.54   333.53  1.00  1229.00  1461.00
# ...

# %%
df.describe(include='O').T
# Out:
#                      count unique  \
# make_model           15919      9
# body_type            15569      8
# vat                  11406      2
# type                 15917      5
# warranty              9156    505
# body_color           15322     14
# paint_type           10147      3
# gearing_type         15919      3
# drive_chain           9061      3
# fuel                 15919     77
# emission_class       12291      3
# comfort_convenience  14999   6198
# entertainment_media  14545    346
# extras               12957    659
# safety_security      14937   4443
# upholstery_type      11416      6
#
#                                                                                                  top  \
# make_model                                                                                   Audi A3
# body_type                                                                                     Sedans
# ...

# %% [markdown]
# ### Checking the missing values.

# %%
df.isna().sum()
# df.isna().sum().mean()*100
# Out:
# make_model                   0
# body_type                  350
# price                        0
# vat                       4513
# km                        1024
# prev_owner                6828
# hp                          88
# type                         2
# previous_owners           6640
# warranty                  6763
# body_color                 597
# paint_type                5772
# nr_of_doors                212
# nr_of_seats                977
# gearing_type                 0
# cylinders                 5680
# drive_chain               6858
# fuel                         0
# emission_class            3628
# comfort_convenience        920
# entertainment_media       1374
# extras                    2962
# safety_security            982
# gears                     4712
# age                       1597
# warranty_months          11066
# displacement_cc            496
# weight_kg                 6974
# upholstery_type           4503
# consumption_comb          2033
# ...

# %%
df.isnull().sum()*100 / df.shape[0]
# Out:
# make_model               0.00
# body_type                2.20
# price                    0.00
# vat                     28.35
# km                       6.43
# prev_owner              42.89
# hp                       0.55
# type                     0.01
# previous_owners         41.71
# warranty                42.48
# body_color               3.75
# paint_type              36.26
# nr_of_doors              1.33
# nr_of_seats              6.14
# gearing_type             0.00
# cylinders               35.68
# drive_chain             43.08
# fuel                     0.00
# emission_class          22.79
# comfort_convenience      5.78
# entertainment_media      8.63
# extras                  18.61
# safety_security          6.17
# gears                   29.60
# age                     10.03
# warranty_months         69.51
# displacement_cc          3.12
# weight_kg               43.81
# upholstery_type         28.29
# consumption_comb        12.77
# co_2_emission_g_by_km   15.30
# ...

# %% [markdown]
# ### Look at the counts of columns that have OBJECT datatype

# %%
df.select_dtypes('O').sort_index(axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   body_color           15322 non-null  object
#  1   body_type            15569 non-null  object
#  2   comfort_convenience  14999 non-null  object
#  3   drive_chain          9061 non-null   object
#  4   emission_class       12291 non-null  object
#  5   entertainment_media  14545 non-null  object
#  6   extras               12957 non-null  object
#  7   fuel                 15919 non-null  object
#  8   gearing_type         15919 non-null  object
#  9   make_model           15919 non-null  object
#  10  paint_type           10147 non-null  object
#  11  safety_security      14937 non-null  object
#  12  type                 15917 non-null  object
#  13  upholstery_type      11416 non-null  object
#  14  vat                  11406 non-null  object
# ...

# %%
object_col = df.select_dtypes('O').sort_index(axis=1).columns
object_col

#df.columns[df.dtypes == 'str']
#df.select_dtypes('O').columns
# df.describe(include='O').columns
# Out:
# Index(['body_color', 'body_type', 'comfort_convenience', 'drive_chain',
#        'emission_class', 'entertainment_media', 'extras', 'fuel',
#        'gearing_type', 'make_model', 'paint_type', 'safety_security', 'type',
#        'upholstery_type', 'vat', 'warranty'],
#       dtype='object')

# %%
missing_value_col = []
[missing_value_col.append(i) for i in df.columns if any(df[i].isnull())]
missing_value_col
# Out:
# ['body_type',
#  'vat',
#  'km',
#  'prev_owner',
#  'hp',
#  'type',
#  'previous_owners',
#  'warranty',
#  'body_color',
#  'paint_type',
#  'nr_of_doors',
#  'nr_of_seats',
#  'cylinders',
#  'drive_chain',
#  'emission_class',
#  'comfort_convenience',
#  'entertainment_media',
#  'extras',
#  'safety_security',
#  'gears',
#  'age',
#  'warranty_months',
#  'displacement_cc',
#  'weight_kg',
#  'upholstery_type',
#  'consumption_comb',
#  'co_2_emission_g_by_km']

# %% [markdown]
# ### Detecting strange values (First Look)

# %%
def first_look(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Num_of_Nulls   : ', df[col].isnull().sum())
    print('Num_of_Uniques : ', df[col].nunique())
    print('Duplicates     : ', df.duplicated(subset = None, keep = 'first').sum(), end='\n\n')
    print(df[col].value_counts(dropna = False).sort_index())
    print('END*****************************', end='\n\n')

# %%
def first_looking(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print("--------------------------------")
    print(df[col].value_counts(dropna = False))

# %%
def null_check (col) :
    print("Column name :", col)
    print("--"*30)
    print("Number of nulls :", df[col].isnull().sum())
    print("Percent of nulls :", '%', round((df[col].isnull().sum()/df.shape[0])*100, 2))
    print("Value_counts :", "\n", df[col].value_counts(dropna=False))

# %%
for col in object_col:
    first_looking(col)
# Out:
# column name    :  body_color
# --------------------------------
# per_of_nulls   :  % 3.75
# num_of_nulls   :  597
# num_of_uniques :  14
# --------------------------------
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64
# column name    :  body_type
# --------------------------------
# per_of_nulls   :  % 2.2
# num_of_nulls   :  350
# num_of_uniques :  8
# --------------------------------
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# NaN               350
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
# column name    :  comfort_convenience
# --------------------------------
# per_of_nulls   :  % 5.78
# ...

# %% [markdown]
# ### Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())

# %%
df.isin(['']).sum()
# Out:
# make_model               0
# body_type                0
# price                    0
# vat                      0
# km                       0
# prev_owner               0
# hp                       0
# type                     0
# previous_owners          0
# warranty                 0
# body_color               0
# paint_type               0
# nr_of_doors              0
# nr_of_seats              0
# gearing_type             0
# cylinders                0
# drive_chain              0
# fuel                     0
# emission_class           0
# comfort_convenience      0
# entertainment_media      0
# extras                   0
# safety_security          0
# gears                    0
# age                      0
# warranty_months          0
# displacement_cc          0
# weight_kg                0
# upholstery_type          0
# consumption_comb         0
# co_2_emission_g_by_km    0
# dtype: int64

# %%
def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''\n' "!?|.,*+-_/]['''):
    """
    exclude  - satırlar da kategori ayırım yerleri
    pattern  - satırdaki veriyi ayırma regex
    strip    - alakasız işaretleri kaldırma
    """
    import re
    column = Series.dropna().apply(str).str.strip(strip)
    diff_value = list()
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %% [markdown]
# ## functions to fill the missing values

# %%
def fill_most_freq(df, group_col, col_name):
     
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])
    print("Number of NaN : ", df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))
    
    
#To fill the missing values with the most existing value (mode)

# %%
def fill_prop(df, group_col, col_name):
       
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        df.loc[cond, col_name] = df.loc[cond, col_name].fillna(method="ffill").fillna(method="bfill")
    df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    print("Number of NaN : ", df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))
    
#To fill the missing values with "ffill and bfill method"

# %%
def fill(df, group_col1, group_col2, col_name, method): # method can be either "mode" or "mean" or "median" or "ffill"
        
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])

    elif method == "mean":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df[col_name].mean(), inplace = True)
        
    elif method == "median":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df[col_name].median(), inplace = True)
        
    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("Number of NaN : ",df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))
    
# To fill the missing values with "mode/mean/median/ffill/bfill method"

# %% [markdown]
# ## "make_model"

# %%
first_looking("make_model")
# Out:
# column name    :  make_model
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  9
# --------------------------------
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="make_model", y="price", data=df, whis=5)
plt.show()

# %% [markdown]
# ## "body_type"

# %%
first_looking("body_type")
# Out:
# column name    :  body_type
# --------------------------------
# per_of_nulls   :  % 2.2
# num_of_nulls   :  350
# num_of_uniques :  8
# --------------------------------
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# NaN               350
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.body_type.replace("Other", np.nan, inplace=True) 

# We do NOT have any information about "other". So we have assigned them to "NaN" to use "fillna" function.

# %%
df['body_type'].value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# NaN               350
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df["body_type"].mode()[0]
# Out:
# 'Sedans'

# %%
df["body_type"] = df.groupby("make_model")["body_type"].apply(lambda x: x.fillna(x.mode()[0]))


# fill null values with mode by grouping data according to "make_model"

# %%
first_looking("body_type")
# Out:
# column name    :  body_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  8
# --------------------------------
# Sedans           8005
# Station wagon    3678
# Compact          3242
# Van               817
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.groupby("make_model")["body_type"].describe()
# Out:
#                count unique            top  freq
# make_model
# Audi A1         2614      5         Sedans  1551
# Audi A2            1      1       Off-Road     1
# Audi A3         3097      5         Sedans  2621
# Opel Astra      2526      5  Station wagon  1285
# Opel Corsa      2219      6        Compact  1319
# Opel Insignia   2598      6  Station wagon  1662
# Renault Clio    1839      7         Sedans   984
# Renault Duster    34      1       Off-Road    34
# Renault Espace   991      7            Van   811

# %%
first_looking("vat")
# Out:
# column name    :  vat
# --------------------------------
# per_of_nulls   :  % 28.35
# num_of_nulls   :  4513
# num_of_uniques :  2
# --------------------------------
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %%
fill(df, "make_model", "body_type", "vat", "mode")
# Out:
# Number of NaN :  0
# ------------------
# VAT deductible      15491
# Price negotiable      428
# Name: vat, dtype: int64

# %%
first_looking("type")
# Out:
# column name    :  type
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  2
# num_of_uniques :  5
# --------------------------------
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: type, dtype: int64

# %%
df["type"]=df.type.fillna(df.type.mode()[0])

#mode ile doldurduk

# %%
df["type"].replace('Pre-registered', 'Used', regex=True, inplace= True)

# %%
df["type"].replace("Employee's car", 'Used', regex=True, inplace= True)

# %%
df["type"].replace('Demonstration', 'Used', regex=True, inplace= True)

# %%
first_looking("type")
# Out:
# column name    :  type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# --------------------------------
# Used    14269
# New      1650
# Name: type, dtype: int64

# %%
first_looking("age")
# Out:
# column name    :  age
# --------------------------------
# per_of_nulls   :  % 10.03
# num_of_nulls   :  1597
# num_of_uniques :  4
# --------------------------------
# 1.00    4522
# 3.00    3674
# 2.00    3273
# 0.00    2853
# NaN     1597
# Name: age, dtype: int64

# %%
df['age'].fillna('-', inplace=True)

# %%
df[df["age"] == "-"]["km"].value_counts(dropna=False)
# Out:
# NaN         838
# 10.00       369
# 1.00        146
# 5.00         58
# 20.00        32
# 15.00        21
# 0.00         19
# 11.00        12
# 8.00         11
# 50.00        10
# 12.00         8
# 100.00        8
# 7.00          7
# 3.00          4
# 9.00          4
# 4.00          3
# 250.00        3
# 25.00         3
# 30.00         3
# 3000.00       2
# 39962.00      2
# 2.00          2
# 22627.00      2
# 784.00        1
# 89692.00      1
# 3500.00       1
# 325.00        1
# 497.00        1
# 99.00         1
# 77.00         1
# 40.00         1
# 19500.00      1
# 6100.00       1
# 11000.00      1
# 89982.00      1
# 4307.00       1
# 141.00        1
# 34164.00      1
# 500.00        1
# 150.00        1
# 11200.00      1
# 20768.00      1
# 32084.00      1
# 142.00        1
# 81800.00      1
# 281.00        1
# 6.00          1
# 68485.00      1
# 85000.00      1
# 196.00        1
# 4500.00       1
# 60.00         1
# 5000.00       1
# Name: km, dtype: int64

# %%
cond1 = (df['km'] < 10000)
cond2 = ((df['km'] >= 10000) & (df['km'] < 30000))
cond3 = ((df['km'] >= 30000) & (df['km'] < 50000))
cond4 = (df['km'] >= 50000)

# %%
df.loc[cond1,'age'] = df.loc[cond1,'age'].replace('-', 0)
df.loc[cond2,'age'] = df.loc[cond2,'age'].replace('-', 1)
df.loc[cond3,'age'] = df.loc[cond3,'age'].replace('-', 2)
df.loc[cond4,'age'] = df.loc[cond4,'age'].replace('-', 3)

# %%
first_looking("age")
# Out:
# column name    :  age
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  5
# --------------------------------
# 1.0    4528
# 3.0    3679
# 0.0    3597
# 2.0    3277
# -       838
# Name: age, dtype: int64

# %%
df['age'].replace('-', 0, inplace=True)

# %%
first_looking("age")
# Out:
# column name    :  age
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
# 1.00    4528
# 0.00    4435
# 3.00    3679
# 2.00    3277
# Name: age, dtype: int64

# %%
df.groupby('age').km.mean()
# Out:
# age
# 0.00    1580.45
# 1.00   17883.86
# 2.00   41744.99
# 3.00   77450.06
# Name: km, dtype: float64

# %%
first_looking("km")
# Out:
# column name    :  km
# --------------------------------
# per_of_nulls   :  % 5.26
# num_of_nulls   :  838
# num_of_uniques :  6689
# --------------------------------
# 10.00       1230
# NaN          838
# 1.00         367
# 5.00         170
# 50.00        148
#             ...
# 67469.00       1
# 43197.00       1
# 10027.00       1
# 35882.00       1
# 57.00          1
# Name: km, Length: 6690, dtype: int64

# %%
df.groupby("age").km.mean()
# Out:
# age
# 0.00    1580.45
# 1.00   17883.86
# 2.00   41744.99
# 3.00   77450.06
# Name: km, dtype: float64

# %%
fill_most_freq(df, "age", "km")
# Out:
# Number of NaN :  0
# ------------------
# 10.00       2068
# 1.00         367
# 5.00         170
# 50.00        148
# 100.00       139
#             ...
# 67469.00       1
# 43197.00       1
# 10027.00       1
# 35882.00       1
# 57.00          1
# Name: km, Length: 6689, dtype: int64

# %%
df[df["km"].isna()][["age", "km"]]
# Out:
# Empty DataFrame
# Columns: [age, km]
# Index: []

# %%
first_looking("km")
# Out:
# column name    :  km
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6689
# --------------------------------
# 10.00       2068
# 1.00         367
# 5.00         170
# 50.00        148
# 100.00       139
#             ...
# 67469.00       1
# 43197.00       1
# 10027.00       1
# 35882.00       1
# 57.00          1
# Name: km, Length: 6689, dtype: int64

# %%
plt.figure(figsize=(30,5))
plt.subplot(141)
plt.hist(df.km, bins = 100);

# %%
first_looking("hp")
# Out:
# column name    :  hp
# --------------------------------
# per_of_nulls   :  % 0.55
# num_of_nulls   :  88
# num_of_uniques :  80
# --------------------------------
# 85.00     2542
# 66.00     2122
# 81.00     1402
# 100.00    1308
# 110.00    1112
# 70.00      888
# 125.00     707
# 51.00      695
# 55.00      569
# 118.00     516
# 92.00      466
# 121.00     392
# 147.00     380
# 77.00      345
# 56.00      286
# 54.00      276
# 103.00     253
# 87.00      232
# 165.00     194
# 88.00      177
# 60.00      160
# 162.00      98
# NaN         88
# 74.00       81
# 96.00       72
# 71.00       59
# 101.00      47
# 67.00       40
# 154.00      39
# 122.00      35
# 119.00      30
# 164.00      27
# 135.00      24
# 82.00       22
# 52.00       22
# 78.00       20
# 1.00        20
# 294.00      18
# 146.00      18
# 141.00      16
# 57.00       10
# 104.00       8
# 120.00       8
# 191.00       7
# 112.00       7
# 155.00       6
# 117.00       6
# 184.00       5
# 90.00        4
# ...

# %%
fill(df, "make_model", "body_type", "hp", "mean")
# Out:
# Number of NaN :  0
# ------------------
# 85.00     2542
# 66.00     2122
# 81.00     1402
# 100.00    1308
# 110.00    1112
# 70.00      888
# 125.00     707
# 51.00      695
# 55.00      569
# 118.00     516
# 92.00      466
# 121.00     392
# 147.00     380
# 77.00      345
# 56.00      286
# 54.00      276
# 103.00     253
# 87.00      232
# 165.00     194
# 88.00      177
# 60.00      160
# 162.00      98
# 74.00       81
# 96.00       72
# 71.00       59
# 101.00      47
# 67.00       40
# 154.00      39
# 122.00      35
# 131.75      34
# 119.00      30
# 164.00      27
# 135.00      24
# 82.00       22
# 52.00       22
# 73.87       20
# 1.00        20
# 78.00       20
# 294.00      18
# 146.00      18
# 141.00      16
# 57.00       10
# 104.00       8
# 77.15        8
# 71.92        8
# 120.00       8
# 191.00       7
# 112.00       7
# 155.00       6
# 110.97       6
# 117.00       6
# 184.00       5
# 65.00        4
# 76.00        4
# 116.04       4
# 90.00        4
# ...

# %%
first_looking("prev_owner")
# Out:
# column name    :  prev_owner
# --------------------------------
# per_of_nulls   :  % 42.89
# num_of_nulls   :  6828
# num_of_uniques :  4
# --------------------------------
# 1.00    8294
# NaN     6828
# 2.00     778
# 3.00      17
# 4.00       2
# Name: prev_owner, dtype: int64

# %%
df["prev_owner"].fillna('-',inplace=True)

# %%
first_looking("prev_owner")
# Out:
# column name    :  prev_owner
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  5
# --------------------------------
# 1.0    8294
# -      6828
# 2.0     778
# 3.0      17
# 4.0       2
# Name: prev_owner, dtype: int64

# %%
df.groupby("prev_owner")["price"].describe(include='O')
# Out:
#              count     mean     std      min      25%      50%      75%  \
# prev_owner
# 1.0        8294.00 17215.68 6575.14  5250.00 12680.00 16275.00 20840.00
# 2.0         778.00 14953.49 5208.81  6400.00 10950.00 14990.00 17537.50
# 3.0          17.00 14676.24 5901.81  7500.00 10598.00 13100.00 17900.00
# 4.0           2.00 20150.00 1626.35 19000.00 19575.00 20150.00 20725.00
# -          6828.00 19353.88 8237.16    13.00 13100.00 18500.00 23880.00
#
#                 max
# prev_owner
# 1.0        74600.00
# 2.0        35990.00
# 3.0        27000.00
# 4.0        21300.00
# -          64900.00

# %%
df.drop(["prev_owner"], axis=1, inplace=True)

# %%
first_looking("previous_owners")
# Out:
# column name    :  previous_owners
# --------------------------------
# per_of_nulls   :  % 41.71
# num_of_nulls   :  6640
# num_of_uniques :  5
# --------------------------------
# 1.00    8294
# NaN     6640
# 2.00     778
# 0.00     188
# 3.00      17
# 4.00       2
# Name: previous_owners, dtype: int64

# %%
df.drop(["previous_owners"], axis=1,inplace=True)# "type" column contains enough information to analyze

# %%
first_looking("warranty")
# Out:
# column name    :  warranty
# --------------------------------
# per_of_nulls   :  % 42.48
# num_of_nulls   :  6763
# num_of_uniques :  505
# --------------------------------
# NaN                                                                                  6763
# Euro 6                                                                               1868
# 12 months                                                                            1305
# 24 months                                                                             585
# 4 (Green)                                                                             517
#                                                                                      ...
# 2 months                                                                                1
# 72 months\n,\n125 g CO2/km (comb)                                                       1
# ...

# %%
df["warranty"].fillna("-", inplace = True)

# %%
df.groupby(['make_model', 'age', 'warranty']).price.describe()
# Out:
#                                                        count     mean     std  \
# make_model     age  warranty
# Audi A1        0.00 -                                 360.00 24414.77 3482.34
#                     1 (No sticker)                      1.00 19490.00     NaN
#                     104 g CO2/km (comb)                 8.00 21402.50  727.89
#                     105 g CO2/km (comb)                 7.00 22661.43  236.04
#                     106 g CO2/km (comb)                10.00 22098.00 1141.56
# ...                                                      ...      ...     ...
# Renault Espace 3.00 6 months                           11.00 21212.73 2423.55
#                     6 months\n,\n120 g CO2/km (comb)    2.00 23250.00 6010.41
#                     6 months\n,\n140 g CO2/km (comb)    2.00 19940.00 2064.75
#                     60 months\n,\n125 g CO2/km (comb)   1.00 23890.00     NaN
#                     Euro 6                             10.00 23476.00 3600.65
#
# ...

# %%
df.groupby(["make_model", "warranty"]).price.describe().sort_values(by = ["make_model", "mean"], ascending=False)
# Out:
#                                                   count     mean     std  \
# make_model     warranty
# Renault Espace 174 g CO2/km (comb)                 2.00 53337.50 2245.06
#                152 g CO2/km (comb)                 6.00 51622.50 7557.50
#                24 months\n,\nEuro 6d-TEMP          2.00 49145.00 7035.71
#                24 months\n,\n152 g CO2/km (comb)   2.00 46490.00 4242.64
#                48 months\n,\n139 g CO2/km (comb)   3.00 45125.00 3381.52
# ...                                                 ...      ...     ...
# Audi A1        3 months\n,\n99 g CO2/km (comb)     1.00 13480.00     NaN
#                60 months\n,\n97 g CO2/km (comb)    2.00 13144.50  205.77
#                12 months\n,\nEuro 5                1.00 12990.00     NaN
#                91 g CO2/km (comb)                  1.00 12950.00     NaN
#                23 months\n,\nEuro 6                1.00 12170.00     NaN
#
# ...

# %%
#There are too many nan values. 
#According to the price, age and make_model columns,we decided that data of this column isn't healthy to analyze

df.drop("warranty", axis=1, inplace=True)

# %%
first_looking("warranty_months")
# Out:
# column name    :  warranty_months
# --------------------------------
# per_of_nulls   :  % 69.51
# num_of_nulls   :  11066
# num_of_uniques :  41
# --------------------------------
# NaN      11066
# 12.00     2594
# 24.00     1118
# 60.00      401
# 36.00      279
# 48.00      149
# 6.00       125
# 72.00       59
# 3.00        33
# 23.00       11
# 18.00       10
# 20.00        7
# 25.00        6
# 2.00         5
# 50.00        4
# 26.00        4
# 16.00        4
# 4.00         3
# 1.00         3
# 19.00        3
# 34.00        3
# 13.00        3
# 28.00        2
# 22.00        2
# 14.00        2
# 11.00        2
# 46.00        2
# 21.00        2
# 9.00         2
# 17.00        2
# 45.00        2
# 33.00        1
# 40.00        1
# 65.00        1
# 10.00        1
# 15.00        1
# 7.00         1
# 8.00         1
# 56.00        1
# 49.00        1
# 47.00        1
# 30.00        1
# Name: warranty_months, dtype: int64

# %%
df.groupby(["make_model", "warranty_months"]).price.describe().sort_values(by = ["make_model", "mean"], ascending=False)
# Out:
#                                 count     mean     std      min      25%  \
# make_model     warranty_months
# Renault Espace 48.00            14.00 39806.79 8058.50 19490.00 37035.00
#                16.00             1.00 38890.00     NaN 38890.00 38890.00
#                45.00             1.00 37950.00     NaN 37950.00 37950.00
#                23.00             1.00 37600.00     NaN 37600.00 37600.00
#                25.00             1.00 36498.00     NaN 36498.00 36498.00
# ...                               ...      ...     ...      ...      ...
# Audi A1        23.00             2.00 16560.00 6208.40 12170.00 14365.00
#                47.00             1.00 16370.00     NaN 16370.00 16370.00
#                49.00             1.00 16270.00     NaN 16270.00 16270.00
#                46.00             1.00 15980.00     NaN 15980.00 15980.00
#                26.00             1.00 15840.00     NaN 15840.00 15840.00
#
#                                     50%      75%      max
# ...

# %%
df.groupby(["warranty_months"])['price'].describe(include='O')
# Out:
#                   count     mean      std      min      25%      50%      75%  \
# warranty_months
# 1.00               3.00 18383.33  4269.29 13455.00 17100.00 20745.00 20847.50
# 2.00               5.00 14604.00  2709.37 10750.00 12990.00 15290.00 16990.00
# 3.00              33.00 16278.21  8782.36  5800.00  8900.00 14950.00 17990.00
# 4.00               3.00 19666.67  7922.33 11200.00 16050.00 20900.00 23900.00
# 6.00             125.00 14608.70  6033.52  5900.00  8790.00 13990.00 18900.00
# 7.00               1.00 21480.00      NaN 21480.00 21480.00 21480.00 21480.00
# 8.00               1.00 17500.00      NaN 17500.00 17500.00 17500.00 17500.00
# 9.00               2.00 10797.50     0.71 10797.00 10797.25 10797.50 10797.75
# 10.00              1.00 19990.00      NaN 19990.00 19990.00 19990.00 19990.00
# 11.00              2.00 20897.00  8341.03 14999.00 17948.00 20897.00 23846.00
# 12.00           2594.00 15659.43  5810.19  5250.00 11410.00 14950.00 18990.00
# ...

# %%
#There are** **``too many nan values. 
#According to the price, age and make_model columns,we decided that data of this column isn't healthy to analyze

df.drop("warranty_months", axis=1, inplace=True)

# %%
first_looking("paint_type")
# Out:
# column name    :  paint_type
# --------------------------------
# per_of_nulls   :  % 36.26
# num_of_nulls   :  5772
# num_of_uniques :  3
# --------------------------------
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64

# %%
df["paint_type"].fillna("-", inplace = True)

# %%
df.groupby(["make_model", "body_type", "age", 'paint_type']).price.describe()
# Out:
#                                           count     mean     std      min  \
# make_model     body_type age  paint_type
# Audi A1        Compact   0.00 -          145.00 22082.72 3341.75 14900.00
#                               Metallic   229.00 24622.26 3172.06 17880.00
#                               Uni/basic    2.00 19888.00    0.00 19888.00
#                          1.00 -           56.00 17590.52 2369.31 14220.00
#                               Metallic   212.00 18861.65 2674.02 13980.00
# ...                                         ...      ...     ...      ...
# Renault Espace Van       2.00 Metallic    91.00 26799.30 3337.26 16950.00
#                               Uni/basic    1.00 29200.00     NaN 29200.00
#                          3.00 -           67.00 21713.15 3450.67 12990.00
#                               Metallic   136.00 22317.03 3286.73 12614.00
#                               Uni/basic    3.00 22628.33 2094.72 20995.00
#
# ...

# %%
df.groupby(["make_model", "body_type", 'paint_type']).price.describe().sort_values(by = ["make_model", "body_type", "mean"], ascending = False)
# Out:
#                                            count     mean      std      min  \
# make_model     body_type     paint_type
# Renault Espace Van           Metallic     505.00 31507.81  9533.34 12614.00
#                              -            293.00 30015.82  7147.55 12990.00
#                              Uni/basic     13.00 27971.15  4495.66 20995.00
#                Transporter   Metallic      34.00 22865.82  4255.81 14999.00
#                              -             18.00 22116.61  4248.69 16900.00
#                Station wagon Metallic      63.00 28095.86  8951.32 17900.00
#                              -             28.00 25556.96  8125.11 16900.00
#                Sedans        Metallic      11.00 31266.09  9386.62 18999.00
#                              Uni/basic      3.00 30016.67  1529.98 28250.00
#                              -              7.00 28160.57  6006.63 23800.00
#                Off-Road      Metallic       8.00 25762.50  5385.35 14900.00
# ...

# %%
df["paint_type"].replace("-", np.nan, inplace=True)

# %%
# preferred to fill missing values

for group1 in df["make_model"].unique():
    for group2 in list(df["body_type"].unique()):
        cond2 = (df["make_model"]==group1) & (df["body_type"]==group2)
        df.loc[cond2, "paint_type"] = df.loc[cond2, "paint_type"].fillna(method="ffill").fillna(method="bfill")
                
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1
    df.loc[cond1, "paint_type"] = df.loc[cond1, "paint_type"].fillna(method="ffill").fillna(method="bfill")            
           
df["paint_type"] = df["paint_type"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking("paint_type")
# Out:
# column name    :  paint_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  3
# --------------------------------
# Metallic       15250
# Uni/basic        637
# Perl effect       32
# Name: paint_type, dtype: int64

# %%
first_looking("nr_of_doors")
# Out:
# column name    :  nr_of_doors
# --------------------------------
# per_of_nulls   :  % 1.33
# num_of_nulls   :  212
# num_of_uniques :  6
# --------------------------------
# 5.00    11575
# 4.00     3079
# 3.00      832
# 2.00      219
# NaN       212
# 1.00        1
# 7.00        1
# Name: nr_of_doors, dtype: int64

# %%
#The number of doors of cars changes by theirs make_models and body_types. 
#Therefore, decided to fill missing values with mode value of related group.

for group1 in list(df["make_model"].unique()):
    for group2 in list(df["body_type"].unique()):
        cond1 = df["make_model"]==group1
        cond2 = (df["make_model"]==group1) & (df["body_type"]==group2)
        mode1 = list(df[cond1]["nr_of_doors"].mode())
        mode2 = list(df[cond2]["nr_of_doors"].mode())
        if mode2 != []:
            df.loc[cond2, "nr_of_doors"] = df.loc[cond2, "nr_of_doors"].fillna(df[cond2]["nr_of_doors"].mode()[0])
        elif mode1 != []:
            df.loc[cond2, "nr_of_doors"] = df.loc[cond2, "nr_of_doors"].fillna(df[cond1]["nr_of_doors"].mode()[0])
        else:
            df.loc[cond2, "nr_of_doors"] = df.loc[cond2, "nr_of_doors"].fillna(df["nr_of_doors"].mode()[0])

# %%
first_looking("nr_of_doors")
# Out:
# column name    :  nr_of_doors
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# --------------------------------
# 5.00    11787
# 4.00     3079
# 3.00      832
# 2.00      219
# 1.00        1
# 7.00        1
# Name: nr_of_doors, dtype: int64

# %%
first_looking("nr_of_seats")
# Out:
# column name    :  nr_of_seats
# --------------------------------
# per_of_nulls   :  % 6.14
# num_of_nulls   :  977
# num_of_uniques :  6
# --------------------------------
# 5.00    13336
# 4.00     1125
# NaN       977
# 7.00      362
# 2.00      116
# 6.00        2
# 3.00        1
# Name: nr_of_seats, dtype: int64

# %%
fill(df, "make_model", "body_type", "nr_of_seats", "mode")

 
# Decided to fill missing values according to mode value of related group ("make_model", "body_type").
# Out:
# Number of NaN :  0
# ------------------
# 5.00    14308
# 4.00     1127
# 7.00      362
# 2.00      119
# 6.00        2
# 3.00        1
# Name: nr_of_seats, dtype: int64

# %%
first_looking("gearing_type")
# Out:
# column name    :  gearing_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  3
# --------------------------------
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gearing_type, dtype: int64

# %%
first_looking("cylinders")
# Out:
# column name    :  cylinders
# --------------------------------
# per_of_nulls   :  % 35.68
# num_of_nulls   :  5680
# num_of_uniques :  7
# --------------------------------
# 4.00    8105
# NaN     5680
# 3.00    2104
# 5.00      22
# 6.00       3
# 8.00       2
# 2.00       2
# 1.00       1
# Name: cylinders, dtype: int64

# %%
df["cylinders"].fillna("-", inplace=True)

# %%
df.groupby(["make_model", "body_type", "age", "cylinders"]).price.describe()
# Out:
#                                          count     mean     std      min  \
# make_model     body_type age  cylinders
# Audi A1        Compact   0.00 3.0       185.00 23789.51 3485.13 14900.00
#                               4.0        20.00 25508.05 3304.23 20582.00
#                               -         171.00 23210.80 3391.35 17780.00
#                          1.00 3.0       131.00 18609.00 2704.67 13980.00
#                               4.0        33.00 21175.70 2117.61 16100.00
# ...                                        ...      ...     ...      ...
# Renault Espace Van       2.00 4.0        59.00 26812.37 4035.41 14600.00
#                               8.0         1.00 24990.00     NaN 24990.00
#                               -          79.00 26314.30 2860.47 17480.00
#                          3.00 4.0       134.00 22288.30 3188.10 13000.00
#                               -          72.00 21821.53 3576.38 12614.00
#
# ...

# %%
# Decided to drop this column, because another feature "hp" has less missing values and give similar insight.

df.drop("cylinders", axis=1, inplace=True)

# %%
first_looking("weight_kg")
# Out:
# column name    :  weight_kg
# --------------------------------
# per_of_nulls   :  % 43.81
# num_of_nulls   :  6974
# num_of_uniques :  434
# --------------------------------
# NaN        6974
# 1163.00     574
# 1360.00     356
# 1165.00     301
# 1335.00     242
#            ...
# 1960.00       1
# 1258.00       1
# 1167.00       1
# 1331.00       1
# 2037.00       1
# Name: weight_kg, Length: 435, dtype: int64

# %%
df["weight_kg"].fillna("-", inplace=True)

# %%
df.groupby(["make_model", "body_type","weight_kg"]).price.describe()
# Out:
#                                     count     mean     std      min      25%  \
# make_model     body_type weight_kg
# Audi A1        Compact   102.0       1.00 19229.00     NaN 19229.00 19229.00
#                          1010.0      2.00 15450.00  707.11 14950.00 15200.00
#                          1035.0      6.00 16796.67 2617.87 14390.00 15892.50
#                          1040.0      2.00 20424.50 2933.79 18350.00 19387.25
#                          1065.0     36.00 20971.78 1982.55 15500.00 18987.50
# ...                                   ...      ...     ...      ...      ...
# Renault Espace Van       2037.0      1.00 47950.00     NaN 47950.00 47950.00
#                          2353.0      1.00 22990.00     NaN 22990.00 22990.00
#                          2410.0      1.00 23990.00     NaN 23990.00 23990.00
#                          2471.0      5.00 24738.00 8470.64 17400.00 20900.00
#                          -         377.00 30126.30 7273.48 12614.00 24990.00
#
# ...

# %%
df["weight_kg"].replace("-", np.nan, inplace=True)

# %%
# The weights of cars changes by their "make_models" and "body_type". 
# Therefore,  filled missing values with mode of "make_models" and "body_type" columns.

fill(df, "make_model", "body_type", "weight_kg", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 1163.00    1582
# 1360.00    1419
# 1487.00     966
# 1135.00     837
# 1425.00     744
#            ...
# 1331.00       1
# 1132.00       1
# 1252.00       1
# 1792.00       1
# 2037.00       1
# Name: weight_kg, Length: 434, dtype: int64

# %%
first_looking("drive_chain")
# Out:
# column name    :  drive_chain
# --------------------------------
# per_of_nulls   :  % 43.08
# num_of_nulls   :  6858
# num_of_uniques :  3
# --------------------------------
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64

# %%
df["drive_chain"].fillna("-", inplace=True)

# %%
df.groupby(["make_model", "body_type", "drive_chain"]).price.describe()
# Out:
#                                            count     mean      std      min  \
# make_model     body_type     drive_chain
# Audi A1        Compact       -            352.00 17620.87  4226.12 10490.00
#                              4WD            2.00 14790.00  1258.65 13900.00
#                              front        685.00 20008.22  4511.35  9950.00
#                Coupe         -              2.00 14925.00  1378.86 13950.00
#                Sedans        -            561.00 17830.44  4362.32  8999.00
#                              4WD            1.00 15450.00      NaN 15450.00
#                              front        989.00 19133.79  4441.97 10000.00
#                Station wagon -              3.00 24593.00  7537.22 15890.00
#                              front         18.00 16681.11  2493.67 12950.00
#                Van           front          1.00 29000.00      NaN 29000.00
# Audi A2        Off-Road      front          1.00 28200.00      NaN 28200.00
# ...

# %%
df["drive_chain"].replace("-", np.nan, inplace=True)

# %%
fill(df, "make_model", "body_type", "drive_chain", "mode")
# Out:
# Number of NaN :  0
# ------------------
# front    15711
# 4WD        204
# rear         4
# Name: drive_chain, dtype: int64

# %%
first_looking("fuel")
# Out:
# column name    :  fuel
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  77
# --------------------------------
# Diesel (Particulate Filter)                                                                                                       4315
# Super 95                                                                                                                          3338
# Gasoline                                                                                                                          3175
# Diesel                                                                                                                            2984
# Super 95 / Regular/Benzine 91                                                                                                      424
# Regular/Benzine 91                                                                                                                 354
# ...

# %%
benzine = ["Gasoline", "Regular", "Others", "Super"]
diesel  = ["Biodiesel", "Diesel"]
lpg     = ["Biogas", "CNG", "Domestic gas H", "LPG"]
hibrit  = ['Electric', 'Electric/Gasoline']

def fueltype(x):
    if any(i in x for i in hibrit):
        return "Hybrit"
    elif any(i in x for i in lpg):
        return "LPG/CNG"
    elif any(i in x for i in benzine):
        return "Benzine"
    elif any(i in x for i in diesel):
        return "Diesel"
    else:
        return x

# %%
df["fuel"] = df["fuel"].apply(fueltype)

# %%
df["fuel"].value_counts(dropna=False)
# Out:
# Benzine    8551
# Diesel     7299
# LPG/CNG      64
# Hybrit        5
# Name: fuel, dtype: int64

# %%
first_looking("body_color")
# Out:
# column name    :  body_color
# --------------------------------
# per_of_nulls   :  % 3.75
# num_of_nulls   :  597
# num_of_uniques :  14
# --------------------------------
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64

# %%
# Decided to drop this column, because there null values and not related to "price".

df.drop("body_color", axis=1, inplace=True)

# %%
first_looking("emission_class")
# Out:
# column name    :  emission_class
# --------------------------------
# per_of_nulls   :  % 22.79
# num_of_nulls   :  3628
# num_of_uniques :  3
# --------------------------------
# Euro 6    12173
# NaN        3628
# Euro 5       78
# Euro 4       40
# Name: emission_class, dtype: int64

# %%
df["emission_class"].value_counts(dropna=False)
# Out:
# Euro 6    12173
# NaN        3628
# Euro 5       78
# Euro 4       40
# Name: emission_class, dtype: int64

# %%
df["emission_class"].fillna("-", inplace=True)

# %%
df.groupby([ "fuel", "make_model", "emission_class"]).price.describe()
# Out:
#                                         count     mean     std      min  \
# fuel    make_model     emission_class
# Benzine Audi A1        -               481.00 21065.76 4373.26  9950.00
#                        Euro 4            1.00 12990.00     NaN 12990.00
#                        Euro 5            4.00 16146.75 3746.47 10999.00
#                        Euro 6         1342.00 19686.44 4732.88  8999.00
#         Audi A3        -               196.00 22400.63 5297.11 13100.00
#                        Euro 5            1.00 14550.00     NaN 14550.00
#                        Euro 6          741.00 23064.16 6844.35 10893.00
#         Opel Astra     -               426.00 18332.02 5126.14  8740.00
#                        Euro 5            6.00 12785.00 2898.72  9290.00
#                        Euro 6          953.00 17618.38 4890.20  9500.00
#         Opel Corsa     -               418.00 11561.41 3232.72   331.00
# ...

# %%
df["emission_class"].replace("-", np.nan, inplace=True)

# %%
first_looking("emission_class")
# Out:
# column name    :  emission_class
# --------------------------------
# per_of_nulls   :  % 22.79
# num_of_nulls   :  3628
# num_of_uniques :  3
# --------------------------------
# Euro 6    12173
# NaN        3628
# Euro 5       78
# Euro 4       40
# Name: emission_class, dtype: int64

# %%
fill(df, "make_model", "body_type", "emission_class", "mode")
# Out:
# Number of NaN :  0
# ------------------
# Euro 6    15799
# Euro 5       78
# Euro 4       42
# Name: emission_class, dtype: int64

# %%
first_looking("comfort_convenience")
# Out:
# column name    :  comfort_convenience
# --------------------------------
# per_of_nulls   :  % 5.78
# num_of_nulls   :  920
# num_of_uniques :  6198
# --------------------------------
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# ...

# %%
fill(df, "make_model", "body_type", "comfort_convenience", "mode")
# Out:
# Number of NaN :  0
# ------------------
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   388
# ...

# %%
first_looking("entertainment_media")
# Out:
# column name    :  entertainment_media
# --------------------------------
# per_of_nulls   :  % 8.63
# num_of_nulls   :  1374
# num_of_uniques :  346
# --------------------------------
# NaN                                                                                                 1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                          1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                       982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                             783
# On-board computer,Radio                                                                              487
#                                                                                                     ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                                           1
# ...

# %%
fill(df, "make_model", "body_type", "entertainment_media", "mode")
# Out:
# Number of NaN :  0
# ------------------
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                      1738
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                  1134
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB        1010
# On-board computer                                                                615
# Radio                                                                            558
#                                                                                 ...
# Bluetooth,CD player,MP3                                                            1
# CD player,USB                                                                      1
# Bluetooth,CD player,Digital radio,Radio,USB                                        1
# Bluetooth,CD player,Digital radio,MP3,On-board computer,Radio,Television,USB       1
# Hands-free equipment,On-board computer,Radio,Sound system                          1
# ...

# %%
first_looking("extras")
# Out:
# column name    :  extras
# --------------------------------
# per_of_nulls   :  % 18.61
# num_of_nulls   :  2962
# num_of_uniques :  659
# --------------------------------
# Alloy wheels                                                                                               3245
# NaN                                                                                                        2962
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  577
# Alloy wheels,Touch screen,Voice Control                                                                     541
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# ...

# %%
fill(df, "make_model", "body_type", "extras", "mode")
# Out:
# Number of NaN :  0
# ------------------
# Alloy wheels                                                                                               5786
# Alloy wheels,Touch screen                                                                                   697
# Roof rack                                                                                                   596
# Alloy wheels,Voice Control                                                                                  582
# Alloy wheels,Touch screen,Voice Control                                                                     544
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch                            1
# ...

# %%
first_looking("safety_security")
# Out:
# column name    :  safety_security
# --------------------------------
# per_of_nulls   :  % 6.17
# num_of_nulls   :  982
# num_of_uniques :  4443
# --------------------------------
# NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ...

# %%
fill(df, "make_model", "body_type", "safety_security", "mode")
# Out:
# Number of NaN :  0
# ------------------
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      729
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                 480
# ...

# %%
first_looking("gears")
# Out:
# column name    :  gears
# --------------------------------
# per_of_nulls   :  % 29.6
# num_of_nulls   :  4712
# num_of_uniques :  10
# --------------------------------
# 6.00     5822
# NaN      4712
# 5.00     3239
# 7.00     1908
# 8.00      224
# 9.00        6
# 1.00        2
# 3.00        2
# 4.00        2
# 2.00        1
# 50.00       1
# Name: gears, dtype: int64

# %%
fill(df, "make_model", "body_type", "gears", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 6.00     8410
# 5.00     5363
# 7.00     1908
# 8.00      224
# 9.00        6
# 1.00        2
# 3.00        2
# 4.00        2
# 2.00        1
# 50.00       1
# Name: gears, dtype: int64

# %%
first_looking("displacement_cc")
# Out:
# column name    :  displacement_cc
# --------------------------------
# per_of_nulls   :  % 3.12
# num_of_nulls   :  496
# num_of_uniques :  77
# --------------------------------
# 1598.00     4761
# 999.00      2438
# 1398.00     1314
# 1399.00      749
# 1229.00      677
# 1956.00      670
# 1461.00      595
# 1490.00      559
# NaN          496
# 1422.00      467
# 1197.00      353
# 898.00       351
# 1395.00      320
# 1968.00      301
# 1149.00      288
# 1618.00      212
# 1798.00      210
# 1498.00      196
# 1600.00      130
# 1248.00      110
# 1997.00      103
# 1364.00      102
# 1400.00       90
# 998.00        72
# 1500.00       50
# 2000.00       46
# 1000.00       40
# 1.00          36
# 1998.00       25
# 2480.00       20
# 1200.00       18
# 1984.00       18
# 1397.00       11
# 899.00        11
# 160.00         6
# 929.00         5
# 1499.00        5
# 997.00         4
# 1596.00        4
# 139.00         4
# 900.00         4
# 1599.00        3
# 1199.00        3
# ...

# %%
fill(df, "make_model", "body_type", "displacement_cc", "mode")

# Decided to fill missing values with mode value of related columns,
#because, the displacement of cars are strongly related to "make_models" and "body_types"
# Out:
# Number of NaN :  0
# ------------------
# 1598.00     5044
# 999.00      2467
# 1398.00     1387
# 1399.00      768
# 1229.00      678
# 1956.00      670
# 1461.00      667
# 1490.00      559
# 1422.00      467
# 1197.00      372
# 898.00       351
# 1395.00      320
# 1968.00      301
# 1149.00      288
# 1618.00      212
# 1798.00      210
# 1498.00      196
# 1600.00      130
# 1248.00      110
# 1997.00      103
# 1364.00      102
# 1400.00       90
# 998.00        72
# 1500.00       50
# 2000.00       46
# 1000.00       40
# 1.00          36
# 1998.00       25
# 2480.00       20
# 1200.00       18
# 1984.00       18
# 1397.00       11
# 899.00        11
# 160.00         6
# 929.00         5
# 1499.00        5
# 997.00         4
# 1596.00        4
# 139.00         4
# 900.00         4
# 1599.00        3
# 1199.00        3
# 1396.00        3
# 1495.00        2
# 1589.00        2
# 1300.00        2
# 2.00           2
# 995.00         2
# 1496.00        1
# 890.00         1
# ...

# %%
first_looking("upholstery_type")
# Out:
# column name    :  upholstery_type
# --------------------------------
# per_of_nulls   :  % 28.29
# num_of_nulls   :  4503
# num_of_uniques :  6
# --------------------------------
# Cloth           8423
# NaN             4503
# Part leather    1499
# Full leather    1009
# Other            368
# Velour            60
# alcantara         57
# Name: upholstery_type, dtype: int64

# %%
df.upholstery_type.replace("Other", np.nan, inplace=True)

# %%
fill(df, "make_model", "body_type", "upholstery_type", "mode")
# Out:
# Number of NaN :  0
# ------------------
# Cloth           12887
# Part leather     1508
# Full leather     1407
# Velour             60
# alcantara          57
# Name: upholstery_type, dtype: int64

# %%
df["upholstery_type"].replace('Part leather', 'Full/Part leather', regex=True, inplace= True)

# %%
df["upholstery_type"].replace('Full leather', 'Full/Part leather', regex=True, inplace= True)

# %%
first_looking("upholstery_type")
# Out:
# column name    :  upholstery_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
# Cloth                12887
# Full/Part leather     2915
# Velour                  60
# alcantara               57
# Name: upholstery_type, dtype: int64

# %%
first_looking("consumption_comb")
# Out:
# column name    :  consumption_comb
# --------------------------------
# per_of_nulls   :  % 12.77
# num_of_nulls   :  2033
# num_of_uniques :  72
# --------------------------------
# NaN      2033
# 5.40      770
# 3.90      733
# 4.00      713
# 5.10      657
# 4.40      623
# 5.60      618
# 4.70      602
# 3.80      585
# 4.80      546
# 5.00      545
# 4.50      523
# 5.20      454
# 4.20      435
# 4.60      426
# 4.90      393
# 5.50      380
# 5.30      380
# 3.70      369
# 5.90      369
# 4.10      342
# 5.70      342
# 6.00      331
# 4.30      307
# 3.30      307
# 3.50      288
# 6.20      216
# 3.60      194
# 6.30      181
# 6.10      175
# 5.80      164
# 6.60      148
# 6.80      136
# 3.40      106
# 6.40       75
# 3.00       69
# 7.40       66
# 6.50       43
# 6.70       43
# 7.10       38
# 10.00      34
# 6.90       27
# 3.20       25
# 8.30       20
# 7.60       14
# 7.00       10
# 3.10        7
# 7.20        6
# 7.80        6
# 8.00        5
# 51.00       4
# ...

# %%
def fill_median(df, group_col1, group_col2, group_col3, col_name):
    
    df[col_name].fillna(df.groupby([group_col1, group_col2, group_col3])[col_name].transform("median"), inplace = True)
    df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("median"), inplace = True)
    df[col_name].fillna(df.groupby(group_col1)[col_name].transform("median"), inplace = True)
    df[col_name].fillna(df[col_name].median(), inplace = True)

    print("Number of NaN : ", df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %%
fill_median(df, "make_model", "body_type", "fuel", "consumption_comb")
# Out:
# Number of NaN :  0
# ------------------
# 5.40     986
# 4.00     960
# 3.90     847
# 4.70     783
# 5.60     783
# 5.10     769
# 5.20     685
# 3.80     678
# 4.40     624
# 5.00     554
# 4.80     546
# 4.60     535
# 4.50     523
# 4.90     494
# 3.30     463
# 3.70     442
# 4.20     436
# 5.90     395
# 5.30     390
# 5.50     382
# 5.70     342
# 4.10     342
# 6.00     331
# 4.30     308
# 3.50     288
# 6.20     259
# 3.60     195
# 6.10     182
# 6.30     181
# 5.80     164
# 6.80     156
# 6.60     148
# 3.40     111
# 5.35     101
# 6.40      75
# 3.00      69
# 7.40      66
# 6.70      43
# 6.50      43
# 7.10      38
# 10.00     35
# 6.90      27
# 3.20      25
# 8.30      20
# 7.60      14
# 7.00      10
# 5.85       7
# 3.10       7
# 7.20       6
# 7.80       6
# 8.00       5
# 51.00      4
# 8.60       4
# 1.60       3
# 7.90       3
# 8.70       3
# 38.00      2
# 7.30       2
# 0.00       2
# 8.10       2
# 40.00      2
# 43.00      1
# 13.80      1
# ...

# %%
first_looking("co_2_emission_g_by_km")
# Out:
# column name    :  co_2_emission_g_by_km
# --------------------------------
# per_of_nulls   :  % 15.3
# num_of_nulls   :  2436
# num_of_uniques :  122
# --------------------------------
# NaN        2436
# 120.00      740
# 99.00       545
# 97.00       537
# 104.00      501
#            ...
# 14.00         1
# 1060.00       1
# 51.00         1
# 165.00        1
# 193.00        1
# Name: co_2_emission_g_by_km, Length: 123, dtype: int64

# %%
fill_median(df, "make_model", "body_type", "fuel", "co_2_emission_g_by_km")
# Out:
# Number of NaN :  0
# ------------------
# 120.00      1000
# 104.00       782
# 97.00        631
# 99.00        593
# 124.00       574
#             ...
# 80.00          1
# 51.00          1
# 165.00         1
# 12324.00       1
# 193.00         1
# Name: co_2_emission_g_by_km, Length: 124, dtype: int64

# %%
df.head(3).T
# Out:
#                                                                                                      0  \
# make_model                                                                                     Audi A1
# body_type                                                                                       Sedans
# price                                                                                            15770
# vat                                                                                     VAT deductible
# km                                                                                            56013.00
# hp                                                                                               66.00
# type                                                                                              Used
# paint_type                                                                                    Metallic
# ...

# %%
df.shape
# Out:
# (15919, 25)

# %%
df.isnull().sum()*100 / df.shape[0]
# Out:
# make_model              0.00
# body_type               0.00
# price                   0.00
# vat                     0.00
# km                      0.00
# hp                      0.00
# type                    0.00
# paint_type              0.00
# nr_of_doors             0.00
# nr_of_seats             0.00
# gearing_type            0.00
# drive_chain             0.00
# fuel                    0.00
# emission_class          0.00
# comfort_convenience     0.00
# entertainment_media     0.00
# extras                  0.00
# safety_security         0.00
# gears                   0.00
# age                     0.00
# displacement_cc         0.00
# weight_kg               0.00
# upholstery_type         0.00
# consumption_comb        0.00
# co_2_emission_g_by_km   0.00
# dtype: float64

# %%
df.to_csv("cleaned_scout_car_2_2.csv", index=False)

# %% [markdown]
# <a id="10"></a>
#
# <p style="background-color:romance; color:plum; font-size:220%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height:1.4; font-weight:bold; text-transform: uppercase;">The End of Part Two</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover"></a>
